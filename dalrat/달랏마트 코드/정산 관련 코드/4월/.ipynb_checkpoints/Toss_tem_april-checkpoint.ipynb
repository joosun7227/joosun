# %%
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
virtual_df = pd.read_excel('가상계좌_결제내역_2024.04.01-2024.04.29.xlsx')
credit_df = pd.read_excel('신용·체크카드_결제내역_2024.04.01-2024.04.29.xlsx')
# Out:
# C:\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
tip = pd.read_csv('settlement_order_list_20240428_T.csv')
fie = pd.read_csv('settlement_order_list_20240428_F.csv')
rung = pd.read_csv('settlement_order_list_20240428_R.csv')
hung = pd.read_csv('settlement_order_list_20240428_H.csv')
lee = pd.read_csv('settlement_order_list_20240428_LEE.csv')

# %% [markdown]
# # 컬럼 정리 및 데이터 전처리

# %%
# 필요한 컬럼만 남기기
virtual_df = virtual_df[['결제·취소일시','취소완료일시','주문번호', '결제상태', '입금·취소액']]
credit_df = credit_df[['결제일시', '취소일시', '주문번호', '결제상태', '결제액','취소액']]

# 결제방법 구분하기 + 결제상태 컬럼 만들기
virtual_df['결제방법'] = '가상계좌'
credit_df['결제방법'] = '신용카드'

# 결제방법 컬럼을 앞으로 이동
virtual_df = virtual_df[['결제방법', '결제·취소일시','주문번호', '결제상태', '입금·취소액']]
credit_df = credit_df[['결제방법', '결제일시', '주문번호', '결제상태', '결제액','취소액']]

# '결제상태'가 '완료', '취소요청', '부분취소'인 행만 남기기
virtual_df = virtual_df[virtual_df['결제상태'].isin(['완료', '취소요청', '부분취소'])]
credit_df = credit_df[credit_df['결제상태'].isin(['완료', '취소', '부분취소'])]

# %% [markdown]
# # 취소건 처리

# %%
# 가상계좌 결제내역에서 취소하면 음수로 표시됨
# 신용카드 결제내역에서 취소하면 음수로 표시됨

# %%
# 취소금액 확인하기
# Filter out the rows where '입금·취소액' and '결제액' have been made negative due to cancellation
virtual_df_negatives = virtual_df[virtual_df['입금·취소액'] < 0]
credit_df_negatives = credit_df[credit_df['취소액'] < 0]

# Displaying a sample of the rows where adjustments have been made
virtual_df_negatives
# Out:
#       결제방법              결제·취소일시                   주문번호  결제상태  입금·취소액
# 35    가상계좌  2024-04-26 17:23:12   000002275-1713322680  취소요청  -45000
# 36    가상계좌  2024-04-26 17:21:41   000001967-1712801996  취소요청  -46500
# 111   가상계좌  2024-04-25 19:36:43  3000000755-1713945319  취소요청  -34000
# 112   가상계좌  2024-04-25 19:34:42  3000000738-1713855109  취소요청   -4300
# 113   가상계좌  2024-04-25 19:33:33   000002628-1713923475  취소요청  -12900
# 114   가상계좌  2024-04-25 19:19:02   000002686-1713968138  취소요청 -153499
# 164   가상계좌  2024-04-25 09:29:41   000001977-1712803614  취소요청  -45000
# 165   가상계좌  2024-04-25 09:24:12   000002420-1713529666  취소요청   -3000
# 166   가상계좌  2024-04-25 09:20:55   000002605-1713858788  취소요청  -39000
# 167   가상계좌  2024-04-25 09:16:38  3000000691-1713417751  취소요청   -1500
# 268   가상계좌  2024-04-23 16:46:44  3000000684-1713398133  부분취소 -225000
# 391   가상계좌  2024-04-22 09:57:08  3000000631-1712906890  부분취소 -134000
# 392   가상계좌  2024-04-22 09:36:44  3000000685-1713398794  부분취소  -12600
# 393   가상계좌  2024-04-22 09:33:34  3000000694-1713430703  부분취소  -43600
# 394   가상계좌  2024-04-22 09:30:20   000002040-1712886039  부분취소   -4600
# 537   가상계좌  2024-04-18 18:29:29  3000000581-1712799098  부분취소  -82000
# 538   가상계좌  2024-04-18 18:27:45   000002343-1713417973  부분취소  -21000
# 539   가상계좌  2024-04-18 18:23:49   000002260-1713279287  부분취소   -4700
# 540   가상계좌  2024-04-18 18:17:57   000002019-1712829154  부분취소   -4000
# 541   가상계좌  2024-04-18 18:15:24  3000000653-1713238910  부분취소  -20000
# 728   가상계좌  2024-04-16 11:21:04  3000000640-1713149436  부분취소   -2100
# 729   가상계좌  2024-04-16 11:20:38   000001991-1712811933  부분취소   -3300
# 730   가상계좌  2024-04-16 11:19:36   000001927-1712742610  부분취소   -3250
# 731   가상계좌  2024-04-16 11:19:05   000002062-1712902026  부분취소  -12600
# 732   가상계좌  2024-04-16 11:18:26   000002031-1712846652  부분취소   -8600
# 733   가상계좌  2024-04-16 11:17:48   000002034-1712872137  부분취소   -7200
# 735   가상계좌  2024-04-16 11:17:09   000002009-1712818781  부분취소   -4700
# 736   가상계좌  2024-04-16 11:14:03   000001914-1712671909  부분취소   -7600
# 895   가상계좌  2024-04-12 12:15:55  3000000563-1712630489  부분취소  -56000
# 1048  가상계좌  2024-04-09 18:28:19  3000000245-1710296271  부분취소  -63200
# 1075  가상계좌  2024-04-08 17:28:31   000001801-1712299841  부분취소  -19000
# 1076  가상계좌  2024-04-08 17:26:52   000001705-1712138173  부분취소   -9500
# 1286  가상계좌  2024-04-03 19:42:20   000001421-1711533047  부분취소  -21100
# 1287  가상계좌  2024-04-03 19:10:11  3000000492-1711952332  부분취소   -1400
# 1288  가상계좌  2024-04-03 19:04:15   000001575-1711948359  부분취소  -59200
# 1289  가상계좌  2024-04-03 18:45:28   000001505-1711692376  부분취소   -8600
# 1290  가상계좌  2024-04-03 18:41:28  3000000133-1709706154  부분취소  -25000
# 1383  가상계좌  2024-04-02 13:58:27   000001596-1711982609  부분취소   -4000
# 1415  가상계좌  2024-04-01 18:05:11   000001532-1711880465  부분취소   -9500
# 1416  가상계좌  2024-04-01 18:04:37   000001522-1711805831  부분취소   -4400
# 1436  가상계좌  2024-04-01 13:34:32   000001491-1711686948  부분취소   -4400
# 1437  가상계좌  2024-04-01 13:33:16   000001469-1711634391  부분취소   -4400

# %%
credit_df_negatives
# Out:
#     결제방법                 결제일시                   주문번호  결제상태      결제액     취소액
# 9   신용카드  2024-04-24 14:49:44  3000000754-1713937784  부분취소   229700   -2800
# 25  신용카드  2024-04-18 13:52:09  3000000690-1713415929  부분취소   288550  -76000
# 30  신용카드  2024-04-16 13:52:44  3000000654-1713243163  부분취소   920500  -38000
# 82  신용카드  2024-04-04 14:57:02  3000000526-1712210222    취소    42000  -42000
# 83  신용카드  2024-04-03 13:56:14  3000000513-1712120173  부분취소  3205600 -140400
# 98  신용카드  2024-03-27 14:35:41  3000000442-1711517741    취소    46000  -46000

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제방법    93 non-null     object
#  1   결제일시    93 non-null     object
#  2   주문번호    93 non-null     object
#  3   결제상태    93 non-null     object
#  4   결제액     93 non-null     int64
#  5   취소액     93 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 5.1+ KB

# %% [markdown]
# # 두개의 데이터 컬럼 일치 시키기

# %%
# 신용카드 취소액 결제액으로 옮기기
# 취소액이 있는 행을 복제합니다.
cancellation_rows = credit_df[credit_df['취소액'] < 0].copy()

# 복제한 행에서 '결제액'을 '취소액'으로 업데이트합니다.
cancellation_rows['결제액'] = cancellation_rows['취소액']

# 원본 DataFrame에 복제한 행을 추가합니다.
credit_df = pd.concat([credit_df, cancellation_rows], ignore_index=True)

# 취소액 컬럼 없애기
credit_df = credit_df[['결제방법', '결제일시', '주문번호', '결제상태', '결제액']]

# 결과 확인을 위해 처음 몇 행을 출력합니다.
credit_df.head(), cancellation_rows.head()
# Out:
# (   결제방법                 결제일시                   주문번호 결제상태     결제액
#  0  신용카드  2024-04-28 11:27:31  3000000789-1714271250   완료  120000
#  1  신용카드  2024-04-26 14:13:34  3000000782-1714108414   완료   47600
#  2  신용카드  2024-04-26 10:40:45  3000000777-1714095644   완료   54200
#  3  신용카드  2024-04-25 19:41:15   000002733-1714041675   완료   87500
#  4  신용카드  2024-04-25 16:52:23  3000000774-1714031543   완료  105600,
#      결제방법                 결제일시                   주문번호  결제상태     결제액     취소액
#  9   신용카드  2024-04-24 14:49:44  3000000754-1713937784  부분취소   -2800   -2800
#  25  신용카드  2024-04-18 13:52:09  3000000690-1713415929  부분취소  -76000  -76000
#  30  신용카드  2024-04-16 13:52:44  3000000654-1713243163  부분취소  -38000  -38000
#  82  신용카드  2024-04-04 14:57:02  3000000526-1712210222    취소  -42000  -42000
#  83  신용카드  2024-04-03 13:56:14  3000000513-1712120173  부분취소 -140400 -140400)

# %%
# 컬럼 명 일치시키기
credit_df = credit_df.rename(columns={'결제일시': '결제·취소일시', '결제액': '입금·취소액'})

# %% [markdown]
# # 데이터 합치기

# %%
combined_df = pd.concat([virtual_df, credit_df], ignore_index=True)

# %%
virtual_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1468
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   결제방법     1302 non-null   object
#  1   결제·취소일시  1302 non-null   object
#  2   주문번호     1302 non-null   object
#  3   결제상태     1302 non-null   object
#  4   입금·취소액   1302 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 61.0+ KB

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   결제방법     99 non-null     object
#  1   결제·취소일시  99 non-null     object
#  2   주문번호     99 non-null     object
#  3   결제상태     99 non-null     object
#  4   입금·취소액   99 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   결제방법     1401 non-null   object
#  1   결제·취소일시  1401 non-null   object
#  2   주문번호     1401 non-null   object
#  3   결제상태     1401 non-null   object
#  4   입금·취소액   1401 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 54.9+ KB

# %%
combined_df
# Out:
#       결제방법              결제·취소일시                   주문번호  결제상태  입금·취소액
# 0     가상계좌  2024-04-29 04:53:58   000002830-1714315784    완료   50650
# 1     가상계좌  2024-04-29 04:53:57   000002829-1714314365    완료   30700
# 2     가상계좌  2024-04-29 04:52:20   000002828-1714312839    완료   66200
# 3     가상계좌  2024-04-29 04:52:18   000002825-1714308246    완료  105750
# 4     가상계좌  2024-04-29 04:52:17   000002823-1714307218    완료   53450
# ...    ...                  ...                    ...   ...     ...
# 1396  신용카드  2024-04-18 13:52:09  3000000690-1713415929  부분취소  -76000
# 1397  신용카드  2024-04-16 13:52:44  3000000654-1713243163  부분취소  -38000
# 1398  신용카드  2024-04-04 14:57:02  3000000526-1712210222    취소  -42000
# 1399  신용카드  2024-04-03 13:56:14  3000000513-1712120173  부분취소 -140400
# 1400  신용카드  2024-03-27 14:35:41  3000000442-1711517741    취소  -46000
#
# [1401 rows x 5 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   결제방법     1297 non-null   object
#  1   결제·취소일시  1297 non-null   object
#  2   주문번호     1297 non-null   object
#  3   결제상태     1297 non-null   object
#  4   입금·취소액   1297 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 50.8+ KB

# %% [markdown]
# # 주문건에 이름붙이기

# %%
def adjust_order_number(order_number):
    # order_number를 문자열로 변환
    order_number_str = str(order_number)
    # "-"를 기준으로 분리하고 첫 번째 부분을 선택
    processed_order_number = order_number_str.split('-')[0]
    # 선택된 부분이 10자리인 경우는 그대로 반환
    if len(processed_order_number) == 10:
        return processed_order_number
    # 9자리 미만인 경우, 9자리가 되도록 앞쪽을 0으로 채움
    elif len(processed_order_number) < 9:
        return processed_order_number.zfill(9)
    # 그 외의 경우 (즉, 9자리인 경우), 그대로 반환
    else:
        return processed_order_number

# %%
# combined_df의 '주문번호' 컬럼에 정의한 함수 적용
combined_df['주문번호'] = combined_df['주문번호'].apply(adjust_order_number)

# %%
# 각 데이터프레임의 'Order No' 컬럼에 adjust_order_number 함수 적용
for df in [tip, rung, fie, hung]:
    df['Order No'] = df['Order No'].apply(adjust_order_number)

# %%
# 각 엑셀 파일에 'operator' 컬럼 추가하고, 파일명에 따라 해당하는 값을 할당하기
fie['operator'] = 'fie'
hung['operator'] = 'hung'
rung['operator'] = 'rung'
tip['operator'] = 'tip'
lee['operator'] = 'lee'

# %%
# '고객 이름' 컬럼이 모든 파일에 있다고 가정하고, 필요한 컬럼만 선택하기
# 여기서 '고객명'이 고객 이름을 나타내는 컬럼이라고 가정합니다. 실제 컬럼 이름에 맞게 조정해 주세요.
fie = fie[['Order No', '고객 이름', 'operator']]
hung = hung[['Order No', '고객 이름', 'operator']]
rung = rung[['Order No', '고객 이름', 'operator']]
tip = tip[['Order No', '고객 이름', 'operator']]
lee = lee[['Order No', '고객 이름', 'operator']]

# %%
# 모든 엑셀 파일을 하나의 데이터프레임으로 합치기
source_dfs_combined = pd.concat([fie, hung, rung, tip,lee])
source_dfs_combined = source_dfs_combined.drop_duplicates(subset=['Order No'], keep='first')

# %%
# '주문번호' 컬럼을 'Order No'로 이름 변경
combined_df.rename(columns={'주문번호': 'Order No'}, inplace=True)

# %%
# 병합 시 'operator' 컬럼과 '고객 이름' 컬럼을 활용해 각 주문이 어느 파일에서 왔는지와 고객 이름을 표시하기
merged_df = pd.merge(combined_df, source_dfs_combined[['Order No', '고객 이름', 'operator']], on='Order No', how='left')

# %%
merged_df
# Out:
#       결제방법              결제·취소일시    Order No  결제상태  입금·취소액            고객 이름  \
# 0     가상계좌  2024-04-29 04:53:58   000002830    완료   50650              NaN
# 1     가상계좌  2024-04-29 04:53:57   000002829    완료   30700              NaN
# 2     가상계좌  2024-04-29 04:52:20   000002828    완료   66200              NaN
# 3     가상계좌  2024-04-29 04:52:18   000002825    완료  105750              NaN
# 4     가상계좌  2024-04-29 04:52:17   000002823    완료   53450              NaN
# ...    ...                  ...         ...   ...     ...              ...
# 1396  신용카드  2024-04-18 13:52:09  3000000690  부분취소  -76000     1_호원코퍼레이션 _H
# 1397  신용카드  2024-04-16 13:52:44  3000000654  부분취소  -38000  1_CU 홍성대학원룸점 _H
# 1398  신용카드  2024-04-04 14:57:02  3000000526    취소  -42000          1_태평 _H
# 1399  신용카드  2024-04-03 13:56:14  3000000513  부분취소 -140400    1_ 아시아푸드마트 _H
# 1400  신용카드  2024-03-27 14:35:41  3000000442    취소  -46000              NaN
#
#      operator
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1396     hung
# 1397     hung
# 1398     hung
# 1399     hung
# 1400      NaN
#
# [1401 rows x 7 columns]

# %%
merged_df.to_excel('4월 정산.xlsx', index=False)

# %% [markdown]
# # EDA

# %%
# Excel 파일 불러오기
df = pd.read_excel('4월정산_modi.xlsx')

# %%
# Operator 별 금액 집계
operator_amounts = df.groupby('operator')['입금·취소액'].sum()

# 고객 이름 별 금액 집계
customer_amounts = df.groupby('고객 이름')['입금·취소액'].sum()

# 결과 출력
print("Operator 별 금액:")
print(operator_amounts)

print("고객 이름 별 금액:")
# Out:
# Operator 별 금액:
# operator
# fie     77349950
# hung    74427600
# rung    42355000
# tip     62882650
# Name: 입금·취소액, dtype: int64
# 고객 이름 별 금액:

# %%
customer_amounts
# Out:
# 고객 이름
# 1_ 88마트 _R         4162500
# 1_ GM마트 _H          123200
# 1_ Hur Ye Ji _F      57500
# 1_ KING PETC _T    3449100
# 1_ Lee sang _F      179700
#                     ...
# 테이스트타일랜드 _T         328000
# 팟 타이 랜드 _R          297800
# 포니케이크 _T            111800
# 한한 _R              3333700
# 홍성용 _T              386600
# Name: 입금·취소액, Length: 241, dtype: int64

# %%
import matplotlib.pyplot as plt

# Operator 별 금액 시각화
operator_amounts.plot(kind='barh', color='skyblue')
plt.title('Operator 별 금액')
plt.xlabel('금액')
plt.ylabel('Operator')
plt.show()
# Out:
# C:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Excel 파일로 저장
with pd.ExcelWriter('amounts_summary.xlsx') as writer:
    operator_amounts.to_excel(writer, sheet_name='담당자별')
    customer_amounts.to_excel(writer, sheet_name='거래처별')

print("엑셀 파일이 생성되었습니다.")
# Out:
# 엑셀 파일이 생성되었습니다.

# %% [markdown]
# # 과세 면세 세액 확인

# %%
# 여신금액 합친 데이터 불러오기
toss_df = pd.read_excel('4월 매출 원 데이터.xlsx')
# 사이트 매출 불러오기
site_df = pd.read_csv('settlement_order_summary_20240401.csv')

# %%
# 토스 데이터를 고객 이름 별로 묶기
toss_customer_df = toss_df.groupby(['고객 이름', '결제방법', 'operator'])['입금·취소액'].sum().reset_index()

# %% [markdown]
# ## site_df 가 믿을만 한가?

# %%
toss_customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   고객 이름     421 non-null    object
#  1   결제방법      421 non-null    object
#  2   operator  421 non-null    object
#  3   입금·취소액    421 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 13.3+ KB

# %%
site_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   관리자                     267 non-null    object
#  1   Customer ID             267 non-null    int64
#  2   고객 이름                   267 non-null    object
#  3   Point (taxation)        267 non-null    float64
#  4   Point (tax)             267 non-null    float64
#  5   Point (tax exemption)   267 non-null    int64
#  6   Point total             267 non-null    int64
#  7   Vbank (taxation)        267 non-null    float64
#  8   Vbank (tax)             267 non-null    float64
#  9   Vbank (tax exemption)   267 non-null    int64
#  10  Vbank total             267 non-null    int64
#  11  Card (taxation)         267 non-null    float64
#  12  Card (tax)              267 non-null    float64
#  13  Card (tax exemption)    267 non-null    int64
#  14  Card total              267 non-null    int64
#  15  Refund (taxation)       267 non-null    float64
#  16  Refund (tax)            267 non-null    float64
#  17  Refund (tax exemption)  267 non-null    int64
#  18  Refund total            267 non-null    float64
#  19  Total (taxation)        267 non-null    float64
#  20  Total (tax)             267 non-null    float64
#  21  Total (tax exemption)   267 non-null    int64
#  22  총합계                     267 non-null    float64
#  23  배송비                     267 non-null    float64
# dtypes: float64(13), int64(9), object(2)
# memory usage: 50.2+ KB

# %% [markdown]
# 토스에서 뽑아낸 고객이름은 421명인데 반해 site_df에서는 267개 정도 밖에 안된다. <br>
# 이름이 다르거나 site_df에서 누락된 금액이 저정도가 되는 것이다.
#
# 정확히 어떤 고객이 누락되었는지 알아보자.

# %%
# 'toss_customer_df'에서 '고객 이름'을 기준으로 'site_df'와 일치하지 않는 데이터 찾기
unmatched_names = set(toss_customer_df['고객 이름']) - set(site_df['고객 이름'])

# 일치하지 않는 고객 이름을 가진 행만 필터링
unmatched_customers = toss_customer_df[toss_customer_df['고객 이름'].isin(unmatched_names)]

# %%
unmatched_customers
# Out:
#                             고객 이름  결제방법 operator   입금·취소액
# 57                     1_SINGHA_R    여신     rung  1987400
# 70                   1_크루아타이깐엥 _H  신용카드     hung   124400
# 75                   1_타이피농 _사 _T  가상계좌      tip    72400
# 82   Asia mart Manseon S23011_F_사  가상계좌      fie   214800
# 84             CHANOKNAN S20259_T  가상계좌      fie  2731000
# ..                            ...   ...      ...      ...
# 415                포야이 아시아마트 _R_사  가상계좌     rung    49600
# 416                      피크닉박스 _H  가상계좌     hung   146200
# 417                         행운 _F  가상계좌      fie  5053500
# 418                    호원코퍼레이션 _H  가상계좌     hung   610300
# 419                    호원코퍼레이션 _H  신용카드     hung  2733550
#
# [258 rows x 4 columns]

# %% [markdown]
# # 그래도 배송비를 구해보자

# %%
# site 데이터와 toss 데이터를 고객이름 기준으로 묶기. 금액은 합치기
merged_df = pd.merge(site_df, toss_customer_df[['고객 이름', '입금·취소액']], on='고객 이름', how='left')

# 배송비 구하기
merged_df['배송비'] = merged_df['입금·취소액'] - merged_df['총합계']

# %%
# 고객이름 불일치 
unmatched_entries = merged_df['입금·취소액'].isna()
# 불일치 하면 배송비는 0으로 채움
merged_df['배송비'].fillna(0, inplace=True)

# %%
# 배송비 업데이트
site_df['배송비'] = merged_df['배송비']

# %%
site_df.to_excel('배송비를 구해보자.xlsx', index=False)

# %%
site_df
# Out:
#                 관리자  Customer ID                     고객 이름  Point (taxation)  \
# 0      팁 팁 (ID: 17)   1074100938              KHUNAROOP _T               0.0
# 1      팁 팁 (ID: 17)   1082964075   Kehasathan Daranporn _T               0.0
# 2      팁 팁 (ID: 17)   1043629971             MAYOE CHAR _T               0.0
# 3      룽 룽 (ID: 16)   1059314333               KAMALASK _R               0.0
# 4      팁 팁 (ID: 17)   1076580677  MEETHONG NATTHAPREEYA _T               0.0
# ..              ...          ...                       ...               ...
# 262    룽 룽 (ID: 16)   1083043547                      밍 _R               0.0
# 263    팁 팁 (ID: 17)   1026014846                     온이 _T               0.0
# 264    룽 룽 (ID: 16)   1027117131                   신피양펜 _R               0.0
# 265  파이 파이 (ID: 20)   1058633088              F Tongyai _F               0.0
# 266    팁 팁 (ID: 17)   1041085391               박준식_타이타이 _T               0.0
#
#      Point (tax)  Point (tax exemption)  Point total  Vbank (taxation)  \
# 0            0.0                      0            0          46999.99
# 1            0.0                      0            0        3805005.97
# 2            0.0                      0            0              0.00
# 3            0.0                      0            0        2920727.37
# 4            0.0                      0            0         260272.77
# ..           ...                    ...          ...               ...
# 262          0.0                      0            0          55636.36
# 263          0.0                      0            0          57636.37
# 264          0.0                      0            0         119636.35
# 265          0.0                      0            0          90545.46
# 266          0.0                      0            0         463727.28
#
#      Vbank (tax)  Vbank (tax exemption)  ...  Card total  Refund (taxation)  \
# 0        4700.01                   9200  ...           0                0.0
# 1      380044.03                1566250  ...           0                0.0
# 2           0.00                  54000  ...           0                0.0
# 3      292072.63                 963100  ...           0                0.0
# 4       26027.23                  25600  ...           0                0.0
# ..           ...                    ...  ...         ...                ...
# 262      5563.64                      0  ...           0                0.0
# 263      5763.63                      0  ...           0                0.0
# 264     11963.65                      0  ...           0                0.0
# 265      9054.54                      0  ...           0                0.0
# 266     46372.72                  68600  ...           0                0.0
#
#      Refund (tax)  Refund (tax exemption)  Refund total  Total (taxation)  \
# 0             0.0                       0           0.0          46999.99
# 1             0.0                       0           0.0        3805005.97
# 2             0.0                       0           0.0              0.00
# 3             0.0                       0           0.0        2920727.37
# 4             0.0                       0           0.0         260272.77
# ..            ...                     ...           ...               ...
# 262           0.0                       0           0.0          55636.36
# 263           0.0                       0           0.0          57636.37
# 264           0.0                       0           0.0         119636.35
# 265           0.0                       0           0.0          90545.46
# 266           0.0                       0           0.0         463727.28
#
#      Total (tax)  Total (tax exemption)        총합계        배송비
# 0        4700.01                   9200    60900.0        0.0
# 1      380044.03                1566250  5751300.0 -3784600.0
# 2           0.00                  54000    54000.0        0.0
# 3      292072.63                 963100  4175900.0 -3307300.0
# 4       26027.23                  25600   311900.0        0.0
# ..           ...                    ...        ...        ...
# 262      5563.64                      0    61200.0     8000.0
# 263      5763.63                      0    63400.0    16000.0
# 264     11963.65                      0   131600.0        0.0
# 265      9054.54                      0    99600.0     4000.0
# 266     46372.72                  68600   578700.0    20000.0
#
# [267 rows x 24 columns]

# %% [markdown]
# # 오과장님 결제 내역과 비교해보기

# %%
from openpyxl import load_workbook

# Create a new Workbook for the updated data
updated_wb = Workbook()
updated_ws = updated_wb.active
updated_ws.title = "Additional Rows in New File 1"

# Add the new mismatched rows
for row in new_mismatched_rows_wb1:
    updated_ws.append(row)

# Save the workbook
updated_output_path = '/mnt/data/updated_additional_rows.xlsx'
updated_wb.save(updated_output_path)

updated_output_path
# Out:
# C:\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (94,
#  1526,
#  [('상점아이디(MID)',
#    '결제일시',
#    '취소일시',
#    '주문번호',
#    '결제상태',
#    '구매자명',
#    '결제액',
#    '취소액',
#    '결제수단',
#    '결제기관',
#    '구매상품',
#    '안내메시지',
#    '승인번호',
#    '취소자'),
#   ('kvp_darlra4f33',
#    '2024-03-30 19:05:36',
#    None,
#    '3000000475-1711793136',
#    '완료',
#    '1********H',
#    67000.0,
#    0.0,
#    '일반',
#    '삼성',
#    'Dalrat 3000000475',
#    '거래성공',
#    '96073043',
#    None),
#   ('kvp_darlra4f33',
#    '2024-03-29 16:47:15',
#    None,
#    '3000000474-1711698435',
#    '완료',
#    'S2************시아',
#    287400.0,
#    0.0,
#    '일반',
#    '신한',
#    'Dalrat 3000000474',
#    '거래성공',
#    '31600433',
#    None),
#   ('kvp_darlra4f33',
#    '2024-03-29 16:16:57',
#    None,
#    '3000000473-1711696617',
#    '완료',
#    'S2************외동',
#    53400.0,
#    0.0,
#    '일반',
#    '삼성',
#    'Dalrat 3000000473',
#    '거래성공',
#    '18274327',
#    None),
#   ('kvp_darlra4f33',
#    '2024-03-29 14:52:09',
#    None,
#    '3000000470-1711691528',
#    '완료',
#    'S2************외동',
#    81800.0,
#    0.0,
#    '일반',
#    '삼성',
#    'Dalrat 3000000470',
#    '거래성공',
#    '70788156',
#    None)],
#  [('상점아이디(MID)',
#    '가상계좌 발급일시',
#    '가상계좌 만료일시',
#    '결제·취소일시',
#    '취소완료일시',
#    '주문번호',
#    '결제상태',
#    '현금영수증 발급 상태',
#    '구매자명',
#    '입금자명',
#    '입금·취소액',
#    '은행',
#    '구매상품',
#    '안내메세지',
#    '취소자'),
#   ('darlra9tr5',
#    '2024-03-31 06:48:17',
#    '2024-04-07 06:48:17',
#    '2024-03-31 22:41:49',
#    None,
#    '000001524-1711835296',
#    '완료',
#    '발급 완료',
#    '조****_',
#    'KA******AM',
#    92500.0,
#    'KEB하나',
#    'Dalrat 000001524',
#    '',
#    None),
#   ('darlra9tr5',
#    '2024-03-31 19:32:02',
#    '2024-04-07 19:32:02',
#    '2024-03-31 22:40:27',
#    None,
#    '000001533-1711881121',
#    '완료',
#    '발급 완료',
#    'Ki****************** -',
#    'KA******AM',
#    34100.0,
#    'KEB하나',
#    'Dalrat 000001533',
#    '',
#    None),
#   ('darlra9tr5',
#    '2024-03-31 19:35:15',
#    '2024-04-07 19:35:15',
#    '2024-03-31 22:39:38',
#    None,
#    '000001534-1711881314',
#    '완료',
#    '발급 완료',
#    'OR**** -',
#    'KA******AM',
#    90350.0,
#    'KEB하나',
#    'Dalrat 000001534',
#    '',
#    None),
#   ('darlra9tr5',
#    '2024-03-31 21:07:27',
#    '2024-04-07 21:07:27',
#    '2024-03-31 22:38:49',
#    None,
#    '000001538-1711886847',
#    '완료',
#    '발급 완료',
#    'Em****** _',
#    'KA******AM',
#    72050.0,
#    'KEB하나',
#    'Dalrat 000001538',
#    '',
#    None)])
