# %%
import pandas as pd

# %%
data = pd.read_excel('면세 계산파트.xlsx')

# %%
data
# Out:
#      발행구분                 매출일시      공급가액       세액  면세       총금액       승인번호  \
# 0     사업자  2024-03-07 16:40:23      1091      109   0      1200  160626548
# 1     사업자  2024-03-19 01:49:44      1400        0   0      1400  160051794
# 2     사업자  2024-03-20 12:51:24      1400        0   0      1400  160429139
# 3     사업자  2024-03-13 12:02:30      1400        0   0      1400  161061185
# 4     사업자  2024-03-26 13:05:17      2545      255   0      2800  160455810
# ...   ...                  ...       ...      ...  ..       ...        ...
# 1198  사업자  2024-03-19 18:36:03   4751827   301673   0   5053500  160825997
# 1199  사업자  2024-03-05 15:49:37   5033773   391227   0   5425000  160496418
# 1200  사업자  2024-03-07 13:09:11   5305636   449164   0   5754800  160472891
# 1201  사업자  2024-03-26 11:00:26   7115018   612982   0   7728000  160298941
# 1202  사업자  2024-03-09 23:07:03  10936864  1042436   0  11979300  160881325
#
#       신분확인뒷4자리  거래구분      용도구분    비고        주문번호  \
# 0         1234  승인거래  소비자소득공제용  일반거래  3000000163
# 1         1234  승인거래  소비자소득공제용  일반거래  3000000334
# 2         1234  승인거래  소비자소득공제용  일반거래        1105
# 3         1234  승인거래  소비자소득공제용  일반거래         785
# 4         1234  승인거래  소비자소득공제용  일반거래        1335
# ...        ...   ...       ...   ...         ...
# 1198      1234  승인거래  소비자소득공제용  일반거래        1080
# 1199      1234  승인거래  소비자소득공제용  일반거래         445
# 1200      1234  승인거래  소비자소득공제용  일반거래         546
# 1201      1234  승인거래  소비자소득공제용  일반거래        1331
# 1202      1234  승인거래  소비자소득공제용  일반거래  3000000199
#
#                                     고객 이름
# 0             S23323_H 마하차이 S23323_H 마하차이
# 1     S20227_R KAMALASK S20227_R KAMALASK
# 2                             KAMALASK _R
# 3         S23189_T Palita S23189_T Palita
# 4                                 마하차이 _H
# ...                                   ...
# 1198                                행운 _F
# 1199          S20204 ANUCHA S20204 ANUCHA
# 1200    S23026_Y_T 타이러브샵 S23026_Y_T 타이러브샵
# 1201                          1_ 타이러브샵 _T
# 1202                               최승민 _F
#
# [1203 rows x 13 columns]

# %%
# 실공급가액 컬럼을 만들고 조건에 따라 값을 설정합니다.
data['실공급가액'] = data.apply(lambda x: x['공급가액'] if x['세액'] == 0 else x['세액'] * 10, axis=1)

# 면세액을 업데이트합니다. 세액이 0인 경우 면세액도 0이 됩니다.
data['면세'] = data.apply(lambda x: 0 if x['세액'] == 0 else x['공급가액'] - x['실공급가액'], axis=1)

# %%
data.to_excel('확인용.xlsx', index=False)

# %%
# 면세액 조건에 따른 업데이트
for index, row in data.iterrows():
    if row['면세'] < 0:
        data.at[index, '실공급가액'] -= row['면세']  # 실공급가액에서 빼줍니다.
        data.at[index, '면세'] += abs(row['면세'])  # 면세액에 더합니다.
    elif row['면세'] <= 10:
        data.at[index, '실공급가액'] += row['면세']  # 실공급가액에 더합니다.
        data.at[index, '면세'] -= row['면세']  # 면세액에서 빼줍니다.
    elif row['면세'] > 10:
        ones_digit = row['면세'] % 10  # 1의 자리
        data.at[index, '실공급가액'] += ones_digit  # 실공급가액에 더합니다.
        data.at[index, '면세'] -= ones_digit  # 면세액에서 빼줍니다.

# %%
# 실공급가액 업데이트 후 실공급가액 컬럼 삭제
data['공급가액'] = data['실공급가액']
data.drop('실공급가액', axis=1, inplace=True)

# %%
data.to_excel('최종.xlsx', index=False)
